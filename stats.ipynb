# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sb
from scipy.stats import uniform

# %%
x = [-0.5, 0, 0.5, 1, 1.5]
y = [1, 0, 2, 1, 0]
plt.plot(x,y)
plt.show()

# %%
v = np.random.randint(low= 1, high= 7, size= 10)
print(v)
print(v.mean())
plt.hist(v, bins=12)
#plt.hist(v , ax=ax0)
#plt.show()
# Out:
# [6 3 6 5 3 2 4 4 6 5]
# 4.4
# (array([1., 0., 0., 2., 0., 0., 2., 0., 0., 2., 0., 3.]),
#  array([2.        , 2.33333333, 2.66666667, 3.        , 3.33333333,
#         3.66666667, 4.        , 4.33333333, 4.66666667, 5.        ,
#         5.33333333, 5.66666667, 6.        ]),
#  <a list of 12 Patch objects>)

# %%
v = np.random.randint(low= 1, high= 7, size= 10000)
#print(v)
print(v.mean())
plt.hist(v, bins=12)
#plt.hist(v , ax=ax0)
#plt.show()
# Out:
# 3.4812
# (array([1701.,    0., 1661.,    0., 1651.,    0.,    0., 1726.,    0.,
#         1634.,    0., 1627.]),
#  array([1.        , 1.41666667, 1.83333333, 2.25      , 2.66666667,
#         3.08333333, 3.5       , 3.91666667, 4.33333333, 4.75      ,
#         5.16666667, 5.58333333, 6.        ]),
#  <a list of 12 Patch objects>)

# %%
x =np.array([1,4,4,3,5,6,3,5,2,3,3,5,3,5,6,8,4])
y =np.array([1,6,4,3,5,7,5,2,1,6,8,5,3,6,6,8,9])
print((x+y)/2)
# Out:
# [1.  5.  4.  3.  5.  6.5 4.  3.5 1.5 4.5 5.5 5.  3.  5.5 6.  8.  6.5]

# %%
d1= np.random.randint(low=1, high=7, size = 10000)
d2= np.random.randint(low=1, high=7, size = 10000)
avg = (np.array(d1)+np.array(d2))/2
#print((d1+d2)/2)
print(avg.mean())
print(avg.var())
sb.distplot(avg,bins=12)
# Out:
# 3.4932
# 1.47525376

# %%
d1= np.random.randint(low=1, high=7, size = 10000)
d2= np.random.randint(low=1, high=7, size = 10000)
d3= np.random.randint(low=1, high=7, size = 10000)
avg = (np.array(d1)+np.array(d2)+np.array(d3))/3

print(avg.mean())
print(avg.var())
sb.distplot(avg,bins=12)
# Out:
# 3.501
# 0.9844434444444445

# %%
d1= np.random.randint(low=1, high=7, size = 10000)
d2= np.random.randint(low=1, high=7, size = 10000)
d3= np.random.randint(low=1, high=7, size = 10000)
d4= np.random.randint(low=1, high=7, size = 10000)

avg = (np.array(d1)+np.array(d2)+np.array(d3)+np.array(d4))/4

print(avg.mean())
print(avg.var())
sb.distplot(avg,bins=12)
# Out:
# 3.494025
# 0.714933049375

# %%
uniform_data = uniform.rvs(size = 10000, loc= 20, scale =30)
sb.distplot(uniform_data, bins = 100)

# %%
x = np.array([2,4,6,8,10,12])
print(x.mean())
print(x.std())
# Out:
# 7.0
# 3.415650255319866
