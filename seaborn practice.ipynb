# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
tips = sb.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Plot boxplot for to know who spends more male or female?

# %%
sb.boxplot(data = tips , x='sex', y='total_bill', hue='sex')

# %%
wom_spend = tips[(tips['sex']=='Female')][['sex', 'total_bill']]
men_spend = tips[tips['sex']=='Male'][['sex', 'total_bill']]
#print(men_spend.head())
#print(wom_spend.head())
#m =tips[['sex','tip']]
#m.head()
fig  = plt.figure()
ax0 = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2) 
wom_spend.plot(kind='box', figsize=(16,5), ax =ax0, vert=False)

men_spend.plot(kind='box', figsize=(16,5), ax =ax1, vert=False)

plt.show()

# %% [markdown]
# # Plot boxplot for analyzing total business per day ?

# %%
plt.figure(figsize=(12,7))
sb.boxplot(data=tips, x='day', y='total_bill', hue= 'day')
plt.xlabel('Days')
plt.ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# # Plot boxplot to know on which days bill generated by male is higher

# %%
plt.figure(figsize =(12,8))
sb.boxplot(data = tips, x='day', y='total_bill', hue='sex')
plt.xlabel('Days')
plt.ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# # on which days smokers visited more?

# %%
plt.figure(figsize=(12,7))
sb.boxplot(data=tips, x='day', y='total_bill', hue='smoker')
#sb.boxplot(data=tips, x='smoker',  y='total_bill', hue='day')

# %% [markdown]
# # on which days people come for lunch or dinner?

# %%
plt.figure(figsize=(10,8))
sb.boxplot(data=tips, x='day', y='total_bill', hue='sex')

# %% [markdown]
# # How many male and how many female come for Lunch or Dinner?

# %%
plt.figure(figsize=(12,8))
sb.boxplot(data=tips, x='sex' , y='total_bill', hue='time')

# %% [markdown]
# # Plot the boxplot for reverse order of days sun,sat?

# %%
plt.figure(figsize=(12,8))
sb.boxplot(data=tips, x='day' , y='total_bill', order=['Sun','Sat','Fri','Thur'])

# %% [markdown]
# # Find out when tip is highest, for lunch or dinner for male and female?

# %%
plt.figure(figsize=(9,6))
sb.boxplot(data=tips,x='time', y='tip', hue='sex')

# %% [markdown]
# # Compare tip for male and female?

# %%
sb.barplot(x = 'sex', y='tip', data= tips)
