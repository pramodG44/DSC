# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn import preprocessing
import sklearn as sk
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_columns', None)

# %%
cancer_df= pd.read_csv('C:/Users/pramo/Desktop/IDeators/data.csv')
cancer_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
cancer_df.drop(['Unnamed: 32', 'id'],inplace = True , axis= 1)

# %%
cancer_df.tail()
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  fractal_dimension_mean  radius_se  texture_se  \
# ...

# %%
cancer_df.isnull().sum().sort_values(ascending= False)
# Out:
# fractal_dimension_worst    0
# area_se                    0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# smoothness_se              0
# symmetry_worst             0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# diagnosis                  0
# dtype: int64

# %%
y= cancer_df['diagnosis']
y.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %%
cancer_df.drop(['diagnosis'], inplace= True, axis =1)
cancer_df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  \
# ...

# %%
cancer_df.shape
# Out:
# (569, 30)

# %%
#fig , ax =plt.subplots(figsize=(18,18))
plt.figure(figsize=(16,16))
ax = sns.heatmap(cancer_df.corr(), annot =True, linewidths= .5,square = True, cbar = True,  fmt= '.2f')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (30.0, 0.0)

# %%
cancer_df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
sns.scatterplot(data = cancer_df, x='radius_mean',y='perimeter_mean')

# %%
sns.countplot(data= pd.DataFrame(y), x="diagnosis")
print(y.value_counts())
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
y =preprocessing.LabelEncoder().fit_transform(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(cancer_df, y, train_size=0.7, random_state = 5)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
ks = 15
accuracy = []
for n in range(1, ks):
    knn = KNeighborsClassifier(n_neighbors= n).fit(x_train,y_train)
    pred = knn.predict(x_test)
    accuracy.append(accuracy_score(pred, y_test))

plt.plot(range(1,ks),accuracy)

# %%
knn = KNeighborsClassifier(n_neighbors= 11).fit(x_train,y_train)
pred = knn.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       115
#            1       0.92      1.00      0.96        56
#
#     accuracy                           0.97       171
#    macro avg       0.96      0.98      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %%
cm = confusion_matrix(pred, y_test, labels=[0,1])
ax =sns.heatmap(cm,annot=True,fmt="d")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (2.0, 0.0)

# %%
cancer_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e1c96d7fb374> in <module>
# ----> 1 cancer_df.head()
#
# NameError: name 'cancer_df' is not defined

# %%
cancer_df.corr()
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...
